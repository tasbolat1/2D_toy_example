# %%
import torch
import matplotlib.pyplot as plt
from torch import distributions
import seaborn as sns
import numpy as np
import torch
import torch.nn as nn
from tqdm.auto import tqdm
import matplotlib as mpl
mpl.rcParams['font.size'] = 14

torch.manual_seed(42)
np.random.seed(42)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

from network import ClassifierNN,load_model_info
from density_utils import draw_density_ratio, refine_sample, refine_sample2, draw_density_ratio2, refine_sample_GP_sklearn

from utils import load_item, show_grasp
from dataset import ToyGraspDataset

# %load_ext autoreload
# %autoreload 2

# %%
dataset = ToyGraspDataset(root='data', size=1200)
data = dataset.data
pos_masks = data[:,2] == 1
neg_masks = ~pos_masks

dataset2 = ToyGraspDataset(root='data', size=1200)
data2 = dataset2.data
pos_masks2 = data2[:,2] == 1
neg_masks2 = ~pos_masks2
# handle_masks = data[:,3] == 1

# %%
# load pos vs neg classifier
f = ClassifierNN([2, 64, 64, 1])
f, info = load_model_info('pos_vs_neg', f)
f = f.to(device)

# %%
fig, ax = plt.subplots(nrows=1, figsize=(8,6))
ax.scatter(data[pos_masks][:,0], data[pos_masks][:,1], marker='.', alpha=1.0, color='b')
ax.scatter(data[neg_masks][:,0], data[neg_masks][:,1], marker='.', alpha=1.0, color='r')
Z, CS = draw_density_ratio(ax=ax,
                   model=f,
                   p_type='p_y_given_x',
                   device=device,
                   x_lim=[0, 224],
                   y_lim=[0, 2*np.pi],
                   cmap='RdBu',
                   step_size=0.05)

ax.set_title(f'Positive ({int(info["pos_samples_size"])}) vs negative ({int(info["neg_samples_size"])})')
fig.colorbar(CS, ax=ax)
ax.set_xlim([0, 224])
ax.set_ylim([0, 2*np.pi])

plt.show()
# Out:
# 0.0 0.999619

# %%
fig, ax = plt.subplots(nrows=1, figsize=(8,6))
ax.scatter(data[pos_masks][:,0], data[pos_masks][:,1], marker='.', alpha=1.0, color='b')
ax.scatter(data[neg_masks][:,0], data[neg_masks][:,1], marker='.', alpha=1.0, color='r')
Z, CS = draw_density_ratio(ax=ax,
                   model=f,
                   p_type='log_density_ratio',
                   device=device,
                   x_lim=[0, 224],
                   y_lim=[0, 2*np.pi],
                   cmap='RdBu_r',
                   step_size=0.05)

ax.set_title(f'Log density ratio')
fig.colorbar(CS, ax=ax)
ax.set_xlim([0, 224])
ax.set_ylim([0, 2*np.pi])

plt.show()
# Out:
# -7.8725634 568.2994

# %%
# refine samples
my_sample = torch.FloatTensor([[25, 0.3],
                               [210, 3]])#[160, 3]
my_sample[:,0] /= 224
my_sample[:,1] /= (2*3.14)

# %%
steps_refinement = 100
# print(info['pos_samples_size'], info['neg_samples_size'])
# print(f)
# print(my_sample)
all_x1, all_v1 = refine_sample(my_sample.to(device), f, steps=steps_refinement,
                               eta=0.00001, noise_factor=0.001,
                              Nq = info['pos_samples_size'], Np = info['neg_samples_size'])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots(nrows=1, figsize=(8,6))
ax.scatter(data[pos_masks][:,0], data[pos_masks][:,1], marker='.', alpha=0.2, color='b')
ax.scatter(data[neg_masks][:,0], data[neg_masks][:,1], marker='.', alpha=0.2, color='r')

plt.scatter(my_sample[:, 0]*224, my_sample[:,1]*(2*3.14), marker='*', color='g', s=200)
for i in range(1, steps_refinement, 1):
    plt.scatter(all_x1[i][:, 0]*224, all_x1[i][:,1]*(2*3.14), marker='d', color='g', s=4)

Z, CS = draw_density_ratio(ax=ax,
                   model=f,
                   p_type='log_density_ratio',
                   device=device,
                   x_lim=[0, 224],
                   y_lim=[0, 2*np.pi],
                   cmap='RdBu_r',
                   step_size=0.05,
                      Np=info['neg_samples_size'], Nq=info['pos_samples_size'])

ax.set_title(f'Log density ratio')
fig.colorbar(CS, ax=ax)
ax.set_xlim([0, 224])
ax.set_ylim([0, 2*np.pi])

plt.show()
# Out:
# -0.8971407 64.7622

# %% [markdown]
# # Sim+ vs Real+

# %%
# load pos vs neg classifier
# f2 = ClassifierNN([2, 32, 1])
f2 = ClassifierNN([2, 64, 64, 1])
f2, info2 = load_model_info('simvsreal', f2)
f2 = f2.to(device)
print(info.keys())
print(info2['pos_samples_size'], info2['neg_samples_size'])



# from the GP classifier
# f2
# Nq = info2['pos_samples_size'], Np = info2['neg_samples_size']
# Out:
# dict_keys(['train_loss', 'train_acc', 'test_loss', 'test_acc', 'pos_samples_size', 'neg_samples_size'])
# 1053.0 3947.0

# %%
fig, ax = plt.subplots(nrows=1, figsize=(10,10))
# ax.scatter(data[handle_masks][:,0], data[handle_masks][:,1], marker='.', alpha=1.0, color='b')
# ax.scatter(data[~handle_masks][:,0], data[~handle_masks][:,1], marker='.', alpha=1.0, color='r')
ax.scatter(data2[pos_masks2][:,0], data2[pos_masks2][:,1], marker='.', alpha=0.2, color='b')
ax.scatter(data2[neg_masks2][:,0], data2[neg_masks2][:,1], marker='.', alpha=0.2, color='r')
Z, CS = draw_density_ratio(ax=ax,
                   model=f2,
                   p_type='p_y_given_x',
                   device=device,
                   x_lim=[0, 224],
                   y_lim=[0, 2*np.pi],
                   cmap='RdBu',
                   step_size=0.05)




ax.set_title(f'Real+ ({int(info2["pos_samples_size"])}) vs Sim+ ({int(info2["neg_samples_size"])})')
fig.colorbar(CS, ax=ax)
ax.set_xlim([0, 224])
ax.set_ylim([0, 2*np.pi])

plt.show()
# Out:
# 0.0 0.99900776

# %% [markdown]
# # SIM VS REAL GP

# %%
steps_refinement = 100


# from the GP classifier
# f2
# Nq = info2['pos_samples_size'], Np = info2['neg_samples_size']

all_x1, all_v1 = refine_sample_GP_sklearn(my_sample.to(device), f2, steps=steps_refinement,
#                                eta=0.0001, noise_factor=0.0000,
                               eta=0.0001, noise_factor=0.0000,
                              Nq = Nq, Np = Np)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [19], in <module>
#       1 steps_refinement = 100
#       4 # from the GP classifier
#       5 # f2
#       6 # Nq = info2['pos_samples_size'], Np = info2['neg_samples_size']
# ----> 8 all_x1, all_v1 = refine_sample_GP_sklearn(my_sample.to(device), f2, steps=steps_refinement,
#       9 #                                eta=0.0001, noise_factor=0.0000,
#      10                                eta=0.0001, noise_factor=0.0000,
#      11                               Nq = Nq, Np = Np)
#
# File ~\Documents\2D_toy_example\density_utils.py:175, in refine_sample_GP_sklearn(x, D, steps, f, eta, noise_factor, decay_type, Nq, Np)
#     173 decay_coeff = decay_func(t, steps)
#     174 decay_coeff = decay_coeff.to(x.device)
# --> 175 v = decay_coeff*_velocity(x, Nq=Nq, Np=Np)
#     176 all_v.append(v.detach().cpu())
#     177 x = x.data + eta * v +\
#     178     np.sqrt(2*eta) * noise_factor * torch.randn_like(x)
#
# File ~\Documents\2D_toy_example\density_utils.py:131, in refine_sample_GP_sklearn.<locals>._velocity(x, Nq, Np)
#     128     x_t.grad.zero_()
#     130 x_t_cpu = x_t.cpu()
# --> 131 d_score = D.predict_proba(x_t_cpu)
#     132 # Z = D.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
#     133
#     134 # print(x_t)
#     135 # print(D)
#     136 # print(d_score)
#     137 # print("=====================")
#     138 Nq = torch.FloatTensor([Nq]).to(x_t.device)
#
# File ~\anaconda3\envs\grasp_pytorch\lib\site-packages\sklearn\gaussian_process\_gpc.py:777, in GaussianProcessClassifier.predict_proba(self, X)
#     770     raise ValueError(
#     771         "one_vs_one multi-class mode does not support "
#     772         "predicting probability estimates. Use "
#     773         "one_vs_rest mode instead."
#     774     )
#     776 if self.kernel is None or self.kernel.requires_vector_input:
# --> 777     X = self._validate_data(X, ensure_2d=True, dtype="numeric", reset=False)
#     778 else:
#     779     X = self._validate_data(X, ensure_2d=False, dtype=None, reset=False)
#
# File ~\anaconda3\envs\grasp_pytorch\lib\site-packages\sklearn\base.py:566, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     564     raise ValueError("Validation should be done on X, y or both.")
#     565 elif not no_val_X and no_val_y:
# --> 566     X = check_array(X, **check_params)
#     567     out = X
#     568 elif no_val_X and not no_val_y:
#
# File ~\anaconda3\envs\grasp_pytorch\lib\site-packages\sklearn\utils\validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# File ~\anaconda3\envs\grasp_pytorch\lib\site-packages\torch\_tensor.py:678, in Tensor.__array__(self, dtype)
#     676     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#     677 if dtype is None:
# --> 678     return self.numpy()
#     679 else:
#     680     return self.numpy().astype(dtype, copy=False)
#
# RuntimeError: Can't call numpy() on Tensor that requires grad. Use tensor.detach().numpy() instead.

# %%
fig, ax = plt.subplots(nrows=1, figsize=(8,6))
# ax.scatter(data[pos_masks][:,0], data[pos_masks][:,1], marker='.', alpha=0.2, color='b')
# ax.scatter(data[neg_masks][:,0], data[neg_masks][:,1], marker='.', alpha=0.2, color='r')
ax.scatter(data2[pos_masks2][:,0], data2[pos_masks2][:,1], marker='.', alpha=0.2, color='b')
ax.scatter(data2[neg_masks2][:,0], data2[neg_masks2][:,1], marker='.', alpha=0.2, color='r')
plt.scatter(my_sample[:, 0]*224, my_sample[:,1]*(2*3.14), marker='*', color='g', s=200)
for i in range(1, steps_refinement, 1):
    plt.scatter(all_x1[i][:, 0]*224, all_x1[i][:,1]*(2*3.14), marker='d', color='g', s=4)


Z, CS = draw_density_ratio(ax=ax,
                   model=f2,
                   p_type='log_density_ratio',
                   device=device,
                   x_lim=[0, 224],
                   y_lim=[0, 2*np.pi],
                   cmap='RdBu_r',
                   step_size=0.05,
                   Np=Np, Nq=Nq)

ax.set_title(f'Log density ratio')
fig.colorbar(CS, ax=ax)
ax.set_xlim([0, 224])
ax.set_ylim([0, 2*np.pi])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <module>
#       7 for i in range(1, steps_refinement, 1):
#       8     plt.scatter(all_x1[i][:, 0]*224, all_x1[i][:,1]*(2*3.14), marker='d', color='g', s=4)
# ---> 11 Z, CS = draw_density_ratio(ax=ax,
#      12                    model=f2,
#      13                    p_type='log_density_ratio',
#      14                    device=device,
#      15                    x_lim=[0, 224],
#      16                    y_lim=[0, 2*np.pi],
#      17                    cmap='RdBu_r',
#      18                    step_size=0.05,
#      19                    Np=Np, Nq=Nq)
#      21 ax.set_title(f'Log density ratio')
#      22 fig.colorbar(CS, ax=ax)
#
# File ~\Documents\2D_toy_example\density_utils.py:30, in draw_density_ratio(ax, model, x_lim, y_lim, step_size, cmap, alpha, device, level, p_type, Np, Nq)
#      28 data = np.c_[xx.ravel(), yy.ravel()]
#      29 dataloader = DataLoader(torch.from_numpy(data).float(), batch_size=15000, shuffle=False)
# ---> 30 model.eval()
#      31 with torch.no_grad():
#      32     zz = []
#
# AttributeError: 'GaussianProcessClassifier' object has no attribute 'eval'

# %% [markdown]
# ### Multiple classifiers

# %%
steps_refinement = 100
all_x8, all_v8 = refine_sample2(my_sample.to(device), f, f2,
                                steps=steps_refinement,
                                eta=0.00004,
                                noise_factor=0.000,
                                Np1=info['neg_samples_size'],
                                Nq1=info['pos_samples_size'],
                                Np2=info2['neg_samples_size'],
                                Nq2=info2['pos_samples_size']
                                )
all_x8 = torch.cat(all_x8).numpy()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# Np1=info['neg_samples_size'],
#                                 Nq1=info['pos_samples_size'],
#                                 Np2=info2['neg_samples_size'],
#                                 Nq2=info2['pos_samples_size']

# %%
fig, ax = plt.subplots(nrows=1, figsize=(8,6))
ax.scatter(data[pos_masks][:,0], data[pos_masks][:,1], marker='.', alpha=0.2, color='b')
ax.scatter(data[neg_masks][:,0], data[neg_masks][:,1], marker='.', alpha=0.2, color='r')

plt.scatter(my_sample[:, 0]*224, my_sample[:,1]*(2*3.14), marker='*', color='g', s=200)
# for i in range(1, steps_refinement, 1):
plt.scatter(all_x8[:,0]*224, all_x8[:,1]*(2*3.14), marker='d', color='g', s=10)

Z, CS = draw_density_ratio2(ax=ax,
                   model1=f,
                   model2=f2,
                   device=device,
                   x_lim=[0, 224],
                   y_lim=[0, 2*np.pi],
                   cmap='RdBu_r',
                   step_size=0.05,
                   Np1=info['neg_samples_size'],
                   Nq1=info['pos_samples_size'],
                   Np2=info2['neg_samples_size'],
                   Nq2=info2['pos_samples_size'])

ax.set_title(f'Log density ratio')
fig.colorbar(CS, ax=ax)
ax.set_xlim([0, 224])
ax.set_ylim([0, 2*np.pi])

plt.show()
# Out:
# -11.699127 110645.01

# %%
item = load_item('fork')

# %%
# from matplotlib.patches import ArrowStyle
from matplotlib import animation
# arrow_style = ArrowStyle("Simple", head_length=.6, head_width=1.0, tail_width=.1)
from matplotlib.patches import Arrow

# %%
# %matplotlib notebook

# %%
sample_stream = all_x8[1::2]

# %%
# def animate_grasp(sample_stream, fname):
fname = 'bad_to_pos_handle'
fig, ax = plt.subplots(nrows=1, figsize=(4, 4))
x, angle = sample_stream[0]
x *= 224
angle *= 2*3.14
x2_coef = np.sin(angle)
x1_coef = np.cos(angle)
x1 = x + x1_coef*50#+50#*50
x2 = 224/2 + x2_coef*50# +50#*50

im = ax.imshow(item, cmap='Greys')
arr1 = Arrow(x1,x2,x+x1_coef*20-x1, 224/2+x2_coef*20-x2, width=15)
arr1 = ax.add_patch(arr1)

x1 = x - x1_coef*50
x2 = 224/2 - x2_coef*50
arrow = Arrow(x1,x2, x-x1_coef*20-x1, 224/2-x2_coef*20-x2, width=15)
arr2 = ax.add_patch(arrow)

origin = ax.scatter(x, 224/2, s=40, color='g')


def init():
    global im, arr1, arr2, origin

    x, angle = sample_stream[0]
    x *= 224
    angle *= 2*3.14
    x2_coef = np.sin(angle)
    x1_coef = np.cos(angle)
    x1 = x + x1_coef*50#+50#*50
    x2 = 224/2 + x2_coef*50# +50#*50

    arr1.remove()
    arr1 = Arrow(x1,x2,x+x1_coef*20-x1, 224/2+x2_coef*20-x2, width=15)
    ax.add_patch(arr1)

    arr2.remove()
    x1 = x - x1_coef*50
    x2 = 224/2 - x2_coef*50
    arrow = Arrow(x1,x2, x-x1_coef*20-x1, 224/2-x2_coef*20-x2, width=15)
    arr2 = ax.add_patch(arrow)


    origin.set_offsets((x, 224/2))
    return im, arr1, arr2, origin

# let us make animation
def animate(i):
    global im, arr1, arr2, origin
    if i <=30:
        init()
        return
    else:
        i = i - 30
    x, angle = sample_stream[i]
    x *= 224
    angle *= 2*3.14
    x2_coef = np.sin(angle)
    x1_coef = np.cos(angle)
    x1 = x + x1_coef*50#+50#*50
    x2 = 224/2 + x2_coef*50# +50#*50

    arr1.remove()
    arrow = Arrow(x1,x2,x+x1_coef*20-x1, 224/2+x2_coef*20-x2, width=15)
    arr1 = ax.add_patch(arrow)

    arr2.remove()
    x1 = x - x1_coef*50
    x2 = 224/2 - x2_coef*50
    arrow = Arrow(x1,x2, x-x1_coef*20-x1, 224/2-x2_coef*20-x2, width=15)
    arr2 = ax.add_patch(arrow)


    origin.set_offsets((x, 224/2))
    return im, arr1, arr2, origin

Writer = animation.writers['ffmpeg']
writer = Writer(fps=30, metadata=dict(artist='Me'), bitrate=20000)

anim = animation.FuncAnimation(fig, animate, init_func=init, interval=1500, blit=True, frames=30+sample_stream.shape[0])
anim.save(f'{fname}.mp4', writer=writer)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="399.75">

# %%
sample_stream = all_x8[::2]

# %%
# def animate_grasp(sample_stream, fname):
fname = 'neg_to_pos'
fig, ax = plt.subplots(nrows=1, figsize=(4, 4))
x, angle = sample_stream[0]
x *= 224
angle *= 2*3.14
x2_coef = np.sin(angle)
x1_coef = np.cos(angle)
x1 = x + x1_coef*50#+50#*50
x2 = 224/2 + x2_coef*50# +50#*50

im = ax.imshow(item, cmap='Greys')
arr1 = Arrow(x1,x2,x+x1_coef*20-x1, 224/2+x2_coef*20-x2, width=15)
arr1 = ax.add_patch(arr1)

x1 = x - x1_coef*50
x2 = 224/2 - x2_coef*50
arrow = Arrow(x1,x2, x-x1_coef*20-x1, 224/2-x2_coef*20-x2, width=15)
arr2 = ax.add_patch(arrow)

origin = ax.scatter(x, 224/2, s=40, color='g')


def init():
    global im, arr1, arr2, origin

    x, angle = sample_stream[0]
    x *= 224
    angle *= 2*3.14
    x2_coef = np.sin(angle)
    x1_coef = np.cos(angle)
    x1 = x + x1_coef*50#+50#*50
    x2 = 224/2 + x2_coef*50# +50#*50

    arr1.remove()
    arr1 = Arrow(x1,x2,x+x1_coef*20-x1, 224/2+x2_coef*20-x2, width=15)
    ax.add_patch(arr1)

    arr2.remove()
    x1 = x - x1_coef*50
    x2 = 224/2 - x2_coef*50
    arrow = Arrow(x1,x2, x-x1_coef*20-x1, 224/2-x2_coef*20-x2, width=15)
    arr2 = ax.add_patch(arrow)


    origin.set_offsets((x, 224/2))
    return im, arr1, arr2, origin

# let us make animation
def animate(i):
    global im, arr1, arr2, origin
    if i <=30:
        init()
        return
    else:
        i = i - 30
    x, angle = sample_stream[i]
    x *= 224
    angle *= 2*3.14
    x2_coef = np.sin(angle)
    x1_coef = np.cos(angle)
    x1 = x + x1_coef*50#+50#*50
    x2 = 224/2 + x2_coef*50# +50#*50

    arr1.remove()
    arrow = Arrow(x1,x2,x+x1_coef*20-x1, 224/2+x2_coef*20-x2, width=15)
    arr1 = ax.add_patch(arrow)

    arr2.remove()
    x1 = x - x1_coef*50
    x2 = 224/2 - x2_coef*50
    arrow = Arrow(x1,x2, x-x1_coef*20-x1, 224/2-x2_coef*20-x2, width=15)
    arr2 = ax.add_patch(arrow)


    origin.set_offsets((x, 224/2))
    return im, arr1, arr2, origin

Writer = animation.writers['ffmpeg']
writer = Writer(fps=30, metadata=dict(artist='Me'), bitrate=20000)

anim = animation.FuncAnimation(fig, animate, init_func=init, interval=1500, blit=True, frames=30+sample_stream.shape[0])
anim.save(f'{fname}.mp4', writer=writer)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="399.75">
